# %%
from scipy import signal
from scipy.fft import fftshift
import matplotlib.pyplot as plt
import numpy as np

# %%
fs = 10e3
N = 1e5
amp = 2 * np.sqrt(2)
noise_power = 0.01 * fs / 2
time = np.arange(N) / float(fs)
mod = 500*np.cos(2*np.pi*0.25*time)
carrier = amp * np.sin(2*np.pi*3e3*time + mod)
noise = np.random.normal(scale=np.sqrt(noise_power), size=time.shape)
noise *= np.exp(-time/5)
x = carrier + noise

f, t, Sxx = signal.spectrogram(x, fs)

# %%
t
# Out:
# array([0.0128, 0.0352, 0.0576, 0.08  , 0.1024, 0.1248, 0.1472, 0.1696,
#        0.192 , 0.2144, 0.2368, 0.2592, 0.2816, 0.304 , 0.3264, 0.3488,
#        0.3712, 0.3936, 0.416 , 0.4384, 0.4608, 0.4832, 0.5056, 0.528 ,
#        0.5504, 0.5728, 0.5952, 0.6176, 0.64  , 0.6624, 0.6848, 0.7072,
#        0.7296, 0.752 , 0.7744, 0.7968, 0.8192, 0.8416, 0.864 , 0.8864,
#        0.9088, 0.9312, 0.9536, 0.976 , 0.9984, 1.0208, 1.0432, 1.0656,
#        1.088 , 1.1104, 1.1328, 1.1552, 1.1776, 1.2   , 1.2224, 1.2448,
#        1.2672, 1.2896, 1.312 , 1.3344, 1.3568, 1.3792, 1.4016, 1.424 ,
#        1.4464, 1.4688, 1.4912, 1.5136, 1.536 , 1.5584, 1.5808, 1.6032,
#        1.6256, 1.648 , 1.6704, 1.6928, 1.7152, 1.7376, 1.76  , 1.7824,
#        1.8048, 1.8272, 1.8496, 1.872 , 1.8944, 1.9168, 1.9392, 1.9616,
#        1.984 , 2.0064, 2.0288, 2.0512, 2.0736, 2.096 , 2.1184, 2.1408,
#        2.1632, 2.1856, 2.208 , 2.2304, 2.2528, 2.2752, 2.2976, 2.32  ,
#        2.3424, 2.3648, 2.3872, 2.4096, 2.432 , 2.4544, 2.4768, 2.4992,
#        2.5216, 2.544 , 2.5664, 2.5888, 2.6112, 2.6336, 2.656 , 2.6784,
#        2.7008, 2.7232, 2.7456, 2.768 , 2.7904, 2.8128, 2.8352, 2.8576,
#        2.88  , 2.9024, 2.9248, 2.9472, 2.9696, 2.992 , 3.0144, 3.0368,
#        3.0592, 3.0816, 3.104 , 3.1264, 3.1488, 3.1712, 3.1936, 3.216 ,
#        3.2384, 3.2608, 3.2832, 3.3056, 3.328 , 3.3504, 3.3728, 3.3952,
#        3.4176, 3.44  , 3.4624, 3.4848, 3.5072, 3.5296, 3.552 , 3.5744,
#        3.5968, 3.6192, 3.6416, 3.664 , 3.6864, 3.7088, 3.7312, 3.7536,
#        3.776 , 3.7984, 3.8208, 3.8432, 3.8656, 3.888 , 3.9104, 3.9328,
#        3.9552, 3.9776, 4.    , 4.0224, 4.0448, 4.0672, 4.0896, 4.112 ,
#        4.1344, 4.1568, 4.1792, 4.2016, 4.224 , 4.2464, 4.2688, 4.2912,
#        4.3136, 4.336 , 4.3584, 4.3808, 4.4032, 4.4256, 4.448 , 4.4704,
#        4.4928, 4.5152, 4.5376, 4.56  , 4.5824, 4.6048, 4.6272, 4.6496,
#        4.672 , 4.6944, 4.7168, 4.7392, 4.7616, 4.784 , 4.8064, 4.8288,
#        4.8512, 4.8736, 4.896 , 4.9184, 4.9408, 4.9632, 4.9856, 5.008 ,
#        5.0304, 5.0528, 5.0752, 5.0976, 5.12  , 5.1424, 5.1648, 5.1872,
#        5.2096, 5.232 , 5.2544, 5.2768, 5.2992, 5.3216, 5.344 , 5.3664,
#        5.3888, 5.4112, 5.4336, 5.456 , 5.4784, 5.5008, 5.5232, 5.5456,
#        5.568 , 5.5904, 5.6128, 5.6352, 5.6576, 5.68  , 5.7024, 5.7248,
#        5.7472, 5.7696, 5.792 , 5.8144, 5.8368, 5.8592, 5.8816, 5.904 ,
#        5.9264, 5.9488, 5.9712, 5.9936, 6.016 , 6.0384, 6.0608, 6.0832,
#        6.1056, 6.128 , 6.1504, 6.1728, 6.1952, 6.2176, 6.24  , 6.2624,
#        6.2848, 6.3072, 6.3296, 6.352 , 6.3744, 6.3968, 6.4192, 6.4416,
#        6.464 , 6.4864, 6.5088, 6.5312, 6.5536, 6.576 , 6.5984, 6.6208,
#        6.6432, 6.6656, 6.688 , 6.7104, 6.7328, 6.7552, 6.7776, 6.8   ,
#        6.8224, 6.8448, 6.8672, 6.8896, 6.912 , 6.9344, 6.9568, 6.9792,
#        7.0016, 7.024 , 7.0464, 7.0688, 7.0912, 7.1136, 7.136 , 7.1584,
#        7.1808, 7.2032, 7.2256, 7.248 , 7.2704, 7.2928, 7.3152, 7.3376,
#        7.36  , 7.3824, 7.4048, 7.4272, 7.4496, 7.472 , 7.4944, 7.5168,
#        7.5392, 7.5616, 7.584 , 7.6064, 7.6288, 7.6512, 7.6736, 7.696 ,
#        7.7184, 7.7408, 7.7632, 7.7856, 7.808 , 7.8304, 7.8528, 7.8752,
#        7.8976, 7.92  , 7.9424, 7.9648, 7.9872, 8.0096, 8.032 , 8.0544,
#        8.0768, 8.0992, 8.1216, 8.144 , 8.1664, 8.1888, 8.2112, 8.2336,
#        8.256 , 8.2784, 8.3008, 8.3232, 8.3456, 8.368 , 8.3904, 8.4128,
#        8.4352, 8.4576, 8.48  , 8.5024, 8.5248, 8.5472, 8.5696, 8.592 ,
#        8.6144, 8.6368, 8.6592, 8.6816, 8.704 , 8.7264, 8.7488, 8.7712,
#        8.7936, 8.816 , 8.8384, 8.8608, 8.8832, 8.9056, 8.928 , 8.9504,
#        8.9728, 8.9952, 9.0176, 9.04  , 9.0624, 9.0848, 9.1072, 9.1296,
#        9.152 , 9.1744, 9.1968, 9.2192, 9.2416, 9.264 , 9.2864, 9.3088,
#        9.3312, 9.3536, 9.376 , 9.3984, 9.4208, 9.4432, 9.4656, 9.488 ,
#        9.5104, 9.5328, 9.5552, 9.5776, 9.6   , 9.6224, 9.6448, 9.6672,
#        9.6896, 9.712 , 9.7344, 9.7568, 9.7792, 9.8016, 9.824 , 9.8464,
#        9.8688, 9.8912, 9.9136, 9.936 , 9.9584, 9.9808])

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2) = plt.subplots(figsize=(10,4))
plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(10,10))
im = ax0.pcolormesh(t, f, Sxx, shading='gouraud')
fig.colorbar(im, ax=ax0)
ax0.set_title('pcolormesh with levels')

im2 = ax1.pcolormesh(t, f, Sxx, shading='gouraud')
fig.colorbar(im2, ax=ax1)

plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
